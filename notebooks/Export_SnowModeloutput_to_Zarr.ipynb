# %% [markdown]
# # Extract SWE data from SnowModel output and export to zarr in time increments
# 3/31/2020. https://github.com/emiliom
#
# This notebook implements a single scheme to export to zarr on either the local file system, MinIO (local S3) or AWS S3, based on user choice (`FS_type` variable).

# %% [markdown]
# ## Notes, background, TO-DOs

# %% [markdown]
# ### Strategies, TO-DOs
# - *Ongoing.* Add more attributes, to enrich the metadata
#     - Global attributes, including ones matching with CF conventions.
#     - Variable attributes, including CF standard name
# - DONE. Read a portion of the file at a time. I can't read it all at once b/c it's larger than my available laptop memory (23 GB vs 15.4 GB). But instead of first writing to incremental netcdf files, it's more practical to read the binary data in the same time segments, and write to zarr instead, concatenating along the time dimension
# - DONE. Keeping default `NaN` for `_FillValue`. xrray auto added `'_FillValue': nan` to the `encoding` of the `swe` array. See [xarray #1598](https://github.com/pydata/xarray/issues/1598) and [this](https://cf-trac.llnl.gov/trac/ticket/52) for background discussions. CF/netCDF don't forbid NaN as `_FillValue`. [NCEI NetCDF Template discourages it](https://www.nodc.noaa.gov/data/formats/netcdf/v2.0/faq.html).
# - DONE. Add dimension variables (time, x, y), with corresponding attributes.
# - DONE. Create scheme that accepts a specified/desired number of time steps in each time increment (tsubset), and from it generates a new sequence specifying the number of time steps in each increment. The last increment (last sequence element) may have a smaller number of time steps
#
# ### References for NetCDF CF/ACDD conventions
# - https://www.nodc.noaa.gov/data/formats/netcdf/v2.0/
# - https://www.nodc.noaa.gov/data/formats/netcdf/v2.0/grid.cdl

# %%
from collections import OrderedDict
from pathlib import Path
import math
from datetime import datetime as dt

import numpy as np
import pandas as pd
import xarray as xr
import zarr
import dask
import s3fs
import boto3

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__, xr.__version__, zarr.__version__, s3fs.__version__
# Out:
# ('1.0.3', '0.15.0', '2.4.0', '0.4.0')

# %%
base_dpth = Path("/usr/mayorgadat/workmain/aarendt/CSO/projectwork/snow_model")

# %% [markdown]
# ## Set XYT dimensions and binary blob file name

# %%
##USER INPUTS## - most of this can be read directly from the .ctl file or the .par file 
#-> need to read in text file

# model filename
inFile = 'swed.gdat'

# start date
st = "2014-10-01"
# end date
ed = "2019-09-29"
# number of timesteps in model run 
timesteps = 365 * 5

# from .ctl file
nx = 1382 # number of cells in the x dimension
ny = 2476 # number of cells in the y dimension
xll = 487200
yll = 4690100
clsz = 100 # cellsize

# %% [markdown]
# ## Prepare derived coordinate (XYT) arrays and variables

# %%
def time_increments(timesteps, target_increments):
    nts_increments = [target_increments] * int(timesteps / target_increments)
    nts_increments.append(timesteps % target_increments)
    nts_increments = np.array(nts_increments)
    nts_increment_offsets = nts_increments.cumsum() - nts_increments
    
    return nts_increments, nts_increment_offsets

# %% [markdown]
# The geographical projection is UTM Zone 12N, `epsg:32612`

# %%
# Easting (X) and Northing (Y) arrays
easting_x = np.arange(xll, xll+nx*clsz, clsz)
northing_y = np.arange(yll, yll+ny*clsz, clsz)

# %%
time_days = pd.date_range(st, periods=timesteps)

# %%
len(easting_x), len(northing_y), timesteps
# Out:
# (1382, 2476, 1825)

# %%
time_days[0], time_days[-1]
# Out:
# (Timestamp('2014-10-01 00:00:00', freq='D'),
#  Timestamp('2019-09-29 00:00:00', freq='D'))

# %% [markdown]
# ## Workhorse functions

# %%
def read_as_xrds_tsubset(fpath, time, y, x, nts, nts_offset=0, minval=0):
    """open grads model output file and output a 
    metadata enriched xarray dataset"""

    nx, ny = len(x), len(y)
    # count : int. Number of items to read. -1 means all items (i.e., the complete file).
    numpy_data = np.fromfile(
        fpath, 
        dtype=np.float32, 
        count=nts*ny*nx,
        offset=4*nts_offset*ny*nx  # offset is in bytes
    ).reshape((nts, ny, nx))
    # Switching to using valid_min attribute instead
    # numpy_data = numpy_data.clip(min=minval)

    time_subset = time[nts_offset:nts_offset+nts]

    # TODO: Generalize attribute assignements to use a dictionary (or OrderedDict)
    #  to be passed to this function

    # Convert data to xarray DataArray, then add variable attributes
    datavar = xr.DataArray(
        numpy_data,
        dims=('time', 'y', 'x'), 
        coords={'time': time_subset, 'y': y, 'x': x}
    )
    datavar.attrs['long_name'] = 'Snow Water Equivalent'
    datavar.attrs['standard_name'] = 'lwe_thickness_of_surface_snow_amount'
    datavar.attrs['units'] = 'meters'
    datavar.attrs['valid_min'] = float(minval)

    ## Create xarray Dataset, including dimension variables
    d = OrderedDict()
    d['time'] = ('time', time_subset)
    d['x'] = ('x', x)
    d['y'] = ('y', y)
    d['swe'] = datavar
    ds = xr.Dataset(d)

    # Add global attributes
    ds.attrs['description'] = "SnowModel model run, SWE variable only"
    ds.attrs['CRS'] = "UTM Zone 12N, EPSG:32612"

    # Add dimension/coordinate variable attributes
    ds.time.attrs['standard_name'] = "time"
    ds.time.attrs['axis'] = "T"

    ds.x.attrs['long_name'] = "Easting"
    ds.x.attrs['units'] = "meters"
    ds.x.attrs['axis'] = "X"

    ds.y.attrs['long_name'] = "Northing"
    ds.y.attrs['units'] = "meters"
    ds.y.attrs['axis'] = "Y"
    
    return ds

# %%
def ds_increment_to_zarr(fs_type, zarrstore, ds, chunk, is_first=False):
    """Chunk and export to Zarr"""
    
    chunked_ds = ds.chunk(chunk)
    
    compute = False if fs_type.endswith('s3') else True
    if is_first:
        store = chunked_ds.to_zarr(
            store=zarrstore,
            mode='w',
            consolidated=True,
            compute=compute
        )
    else:
        store = chunked_ds.to_zarr(
            store=zarrstore,
            mode='a',
            consolidated=True,
            append_dim="time",
            compute=compute
        )
    
    if fs_type.endswith('s3'):
        store.persist(retries=100)

# %% [markdown]
# ## Read binary blob data incrementally and export to Zarr incrementally
# Iterate over nts_increments and nts_increment_offsets, generate xarray Dataset, and write (write first one, then append) each increment to zarr

# %% [markdown]
# ### Configuration for export to Zarr

# %%
# Options: localfs, localminio_s3, aws_s3
FS_type, bucket = "aws_s3", "snowmodel"

# Use -1 to process the entire dataset
timesteps_to_process = -1

# should nts_target_increment be the same as the chunk time size?

# Optimizing for whole-spatial-domain queries
# zarrds = "swe_run_a-geo.zarr"
# nts_target_increment = 4 
# chunk = {'time': 4}

# Optimizing for cell time-series queries
zarrds = "swe_run_a-ts.zarr"
nts_target_increment = 460
chunk = {'time': 460, 'x': 150, 'y': 150}

# %% [markdown]
# ### Execute incremental read and export to Zarr

# %%
nts_increments, nts_increment_offsets = time_increments(timesteps, nts_target_increment)

nts_increments[-3:], nts_increment_offsets
# Out:
# (array([4, 4, 1]),
#  array([   0,    4,    8,   12,   16,   20,   24,   28,   32,   36,   40,
#           44,   48,   52,   56,   60,   64,   68,   72,   76,   80,   84,
#           88,   92,   96,  100,  104,  108,  112,  116,  120,  124,  128,
#          132,  136,  140,  144,  148,  152,  156,  160,  164,  168,  172,
#          176,  180,  184,  188,  192,  196,  200,  204,  208,  212,  216,
#          220,  224,  228,  232,  236,  240,  244,  248,  252,  256,  260,
#          264,  268,  272,  276,  280,  284,  288,  292,  296,  300,  304,
#          308,  312,  316,  320,  324,  328,  332,  336,  340,  344,  348,
#          352,  356,  360,  364,  368,  372,  376,  380,  384,  388,  392,
#          396,  400,  404,  408,  412,  416,  420,  424,  428,  432,  436,
#          440,  444,  448,  452,  456,  460,  464,  468,  472,  476,  480,
#          484,  488,  492,  496,  500,  504,  508,  512,  516,  520,  524,
#          528,  532,  536,  540,  544,  548,  552,  556,  560,  564,  568,
#          572,  576,  580,  584,  588,  592,  596,  600,  604,  608,  612,
#          616,  620,  624,  628,  632,  636,  640,  644,  648,  652,  656,
#          660,  664,  668,  672,  676,  680,  684,  688,  692,  696,  700,
#          704,  708,  712,  716,  720,  724,  728,  732,  736,  740,  744,
#          748,  752,  756,  760,  764,  768,  772,  776,  780,  784,  788,
#          792,  796,  800,  804,  808,  812,  816,  820,  824,  828,  832,
#          836,  840,  844,  848,  852,  856,  860,  864,  868,  872,  876,
#          880,  884,  888,  892,  896,  900,  904,  908,  912,  916,  920,
#          924,  928,  932,  936,  940,  944,  948,  952,  956,  960,  964,
#          968,  972,  976,  980,  984,  988,  992,  996, 1000, 1004, 1008,
#         1012, 1016, 1020, 1024, 1028, 1032, 1036, 1040, 1044, 1048, 1052,
#         1056, 1060, 1064, 1068, 1072, 1076, 1080, 1084, 1088, 1092, 1096,
#         1100, 1104, 1108, 1112, 1116, 1120, 1124, 1128, 1132, 1136, 1140,
#         1144, 1148, 1152, 1156, 1160, 1164, 1168, 1172, 1176, 1180, 1184,
#         1188, 1192, 1196, 1200, 1204, 1208, 1212, 1216, 1220, 1224, 1228,
#         1232, 1236, 1240, 1244, 1248, 1252, 1256, 1260, 1264, 1268, 1272,
#         1276, 1280, 1284, 1288, 1292, 1296, 1300, 1304, 1308, 1312, 1316,
#         1320, 1324, 1328, 1332, 1336, 1340, 1344, 1348, 1352, 1356, 1360,
#         1364, 1368, 1372, 1376, 1380, 1384, 1388, 1392, 1396, 1400, 1404,
#         1408, 1412, 1416, 1420, 1424, 1428, 1432, 1436, 1440, 1444, 1448,
#         1452, 1456, 1460, 1464, 1468, 1472, 1476, 1480, 1484, 1488, 1492,
#         1496, 1500, 1504, 1508, 1512, 1516, 1520, 1524, 1528, 1532, 1536,
#         1540, 1544, 1548, 1552, 1556, 1560, 1564, 1568, 1572, 1576, 1580,
#         1584, 1588, 1592, 1596, 1600, 1604, 1608, 1612, 1616, 1620, 1624,
#         1628, 1632, 1636, 1640, 1644, 1648, 1652, 1656, 1660, 1664, 1668,
#         1672, 1676, 1680, 1684, 1688, 1692, 1696, 1700, 1704, 1708, 1712,
#         1716, 1720, 1724, 1728, 1732, 1736, 1740, 1744, 1748, 1752, 1756,
#         1760, 1764, 1768, 1772, 1776, 1780, 1784, 1788, 1792, 1796, 1800,
#         1804, 1808, 1812, 1816, 1820, 1824]))

# %%
len(time_days), len(nts_increments), len(nts_increment_offsets)
# Out:
# (1825, 457, 457)

# %% [markdown]
# Generic strategy to export to local zarr, MinIO zarr, or AWS S3 zarr

# %%
if FS_type == 'localfs':
    # Looks like `open_zarr` doesn't accept pathlib Paths, so convert to str
    zarrstore = str(base_dpth / bucket / zarrds)
elif FS_type == 'localminio_s3':
    FS = s3fs.S3FileSystem(
        key='minioadmin',
        secret='minioadmin',
        client_kwargs={"endpoint_url": "http://172.17.0.2:9000"}
    )
    zarrstore = s3fs.S3Map(f"{bucket}/{zarrds}", s3=FS)
elif FS_type == 'aws_s3':
    # Use stored credentials file, ~/.aws/credentials
    # Can also pass the credentials here explicitly via parameters
    # aws_access_key_id and aws_secret_access_key, but that's not safe
    aws_session = boto3.Session(
        profile_name='cso',
        aws_session_token=None,
        region_name='us-west-2'
    )
    FS = s3fs.S3FileSystem(session=aws_session)
    zarrstore = s3fs.S3Map(f"{bucket}/{zarrds}", s3=FS)

# %%
print(dt.strftime(dt.utcnow(), '%Y-%m-%dT%H:%M:%SZ'))

if timesteps_to_process < 0:
    nts_increments_to_process = len(nts_increments)
else:
    # rounds up to the next complete increment, not just the number of timesteps
    nts_increments_to_process = math.floor(timesteps_to_process / nts_target_increment + 1)

for nts_i in range(nts_increments_to_process):
    # Read increment from the binary blob
    ds = read_as_xrds_tsubset(inFile, time_days, northing_y, easting_x,
                              nts_increments[nts_i], 
                              nts_offset=nts_increment_offsets[nts_i], 
                              minval=0)
    
    print(
        "**** Data increment: index {idx_start} - {idx_end}, {date_start} - {date_end}".format(
            idx_start=nts_increment_offsets[nts_i],
            idx_end=nts_increment_offsets[nts_i]+nts_increments[nts_i]-1,
            date_start=time_days[nts_increment_offsets[nts_i]],
            date_end=time_days[nts_increment_offsets[nts_i]+nts_increments[nts_i]-1]
        )
    )
    
    # Export increment to zarr
    # print(dt.strftime(dt.utcnow(), '%Y-%m-%dT%H:%M:%SZ'))
    is_first = True if nts_i == 0 else False        
    # %time ds_increment_to_zarr(FS_type, zarrstore, ds, chunk, is_first)
    
print(dt.strftime(dt.utcnow(), '%Y-%m-%dT%H:%M:%SZ'))
# Out:
# 2020-04-01T19:39:46Z
# **** Data increment: index 0 - 3, 2014-10-01 00:00:00 - 2014-10-04 00:00:00
# CPU times: user 204 ms, sys: 32 ms, total: 236 ms
# Wall time: 254 ms
# **** Data increment: index 4 - 7, 2014-10-05 00:00:00 - 2014-10-08 00:00:00
# CPU times: user 163 ms, sys: 13.8 ms, total: 176 ms
# Wall time: 179 ms
# **** Data increment: index 8 - 11, 2014-10-09 00:00:00 - 2014-10-12 00:00:00
# CPU times: user 152 ms, sys: 13.9 ms, total: 165 ms
# Wall time: 165 ms
# **** Data increment: index 12 - 15, 2014-10-13 00:00:00 - 2014-10-16 00:00:00
# CPU times: user 196 ms, sys: 12 ms, total: 208 ms
# Wall time: 207 ms
# **** Data increment: index 16 - 19, 2014-10-17 00:00:00 - 2014-10-20 00:00:00
# CPU times: user 142 ms, sys: 10.1 ms, total: 152 ms
# Wall time: 152 ms
# **** Data increment: index 20 - 23, 2014-10-21 00:00:00 - 2014-10-24 00:00:00
# CPU times: user 189 ms, sys: 16.1 ms, total: 205 ms
# Wall time: 205 ms
# **** Data increment: index 24 - 27, 2014-10-25 00:00:00 - 2014-10-28 00:00:00
# CPU times: user 189 ms, sys: 40.2 ms, total: 229 ms
# Wall time: 229 ms
# **** Data increment: index 28 - 31, 2014-10-29 00:00:00 - 2014-11-01 00:00:00
# CPU times: user 184 ms, sys: 16 ms, total: 200 ms
# Wall time: 200 ms
# **** Data increment: index 32 - 35, 2014-11-02 00:00:00 - 2014-11-05 00:00:00
# CPU times: user 201 ms, sys: 60.2 ms, total: 261 ms
# Wall time: 261 ms
# **** Data increment: index 36 - 39, 2014-11-06 00:00:00 - 2014-11-09 00:00:00
# CPU times: user 191 ms, sys: 23.5 ms, total: 214 ms
# Wall time: 213 ms
# **** Data increment: index 40 - 43, 2014-11-10 00:00:00 - 2014-11-13 00:00:00
# CPU times: user 185 ms, sys: 52.4 ms, total: 238 ms
# Wall time: 237 ms
# **** Data increment: index 44 - 47, 2014-11-14 00:00:00 - 2014-11-17 00:00:00
# CPU times: user 187 ms, sys: 48.7 ms, total: 235 ms
# Wall time: 234 ms
# **** Data increment: index 48 - 51, 2014-11-18 00:00:00 - 2014-11-21 00:00:00
# CPU times: user 195 ms, sys: 39.7 ms, total: 235 ms
# Wall time: 234 ms
# **** Data increment: index 52 - 55, 2014-11-22 00:00:00 - 2014-11-25 00:00:00
# CPU times: user 179 ms, sys: 55.7 ms, total: 234 ms
# Wall time: 233 ms
# **** Data increment: index 56 - 59, 2014-11-26 00:00:00 - 2014-11-29 00:00:00
# CPU times: user 170 ms, sys: 63.6 ms, total: 234 ms
# Wall time: 233 ms
# **** Data increment: index 60 - 63, 2014-11-30 00:00:00 - 2014-12-03 00:00:00
# CPU times: user 183 ms, sys: 51.7 ms, total: 235 ms
# Wall time: 233 ms
# **** Data increment: index 64 - 67, 2014-12-04 00:00:00 - 2014-12-07 00:00:00
# CPU times: user 165 ms, sys: 60.3 ms, total: 225 ms
# Wall time: 224 ms
# **** Data increment: index 68 - 71, 2014-12-08 00:00:00 - 2014-12-11 00:00:00
# CPU times: user 183 ms, sys: 51.6 ms, total: 234 ms
# Wall time: 234 ms
# **** Data increment: index 72 - 75, 2014-12-12 00:00:00 - 2014-12-15 00:00:00
# CPU times: user 168 ms, sys: 60.2 ms, total: 229 ms
# Wall time: 228 ms
# **** Data increment: index 76 - 79, 2014-12-16 00:00:00 - 2014-12-19 00:00:00
# CPU times: user 185 ms, sys: 44.1 ms, total: 229 ms
# Wall time: 228 ms
# **** Data increment: index 1532 - 1535, 2018-12-11 00:00:00 - 2018-12-14 00:00:00
# CPU times: user 237 ms, sys: 78 ms, total: 315 ms
# Wall time: 395 ms
# **** Data increment: index 1536 - 1539, 2018-12-15 00:00:00 - 2018-12-18 00:00:00
# CPU times: user 236 ms, sys: 63.8 ms, total: 300 ms
# Wall time: 305 ms
# **** Data increment: index 1540 - 1543, 2018-12-19 00:00:00 - 2018-12-22 00:00:00
# CPU times: user 236 ms, sys: 69.3 ms, total: 305 ms
# Wall time: 400 ms
# **** Data increment: index 1544 - 1547, 2018-12-23 00:00:00 - 2018-12-26 00:00:00
# CPU times: user 263 ms, sys: 91.5 ms, total: 354 ms
# Wall time: 462 ms
# **** Data increment: index 1548 - 1551, 2018-12-27 00:00:00 - 2018-12-30 00:00:00
# CPU times: user 308 ms, sys: 57 ms, total: 365 ms
# Wall time: 377 ms
# **** Data increment: index 1552 - 1555, 2018-12-31 00:00:00 - 2019-01-03 00:00:00
# CPU times: user 241 ms, sys: 68.8 ms, total: 309 ms
# Wall time: 325 ms
# **** Data increment: index 1556 - 1559, 2019-01-04 00:00:00 - 2019-01-07 00:00:00
# CPU times: user 271 ms, sys: 60.9 ms, total: 332 ms
# Wall time: 492 ms
# **** Data increment: index 1560 - 1563, 2019-01-08 00:00:00 - 2019-01-11 00:00:00
# CPU times: user 239 ms, sys: 68.9 ms, total: 307 ms
# Wall time: 306 ms
# **** Data increment: index 1564 - 1567, 2019-01-12 00:00:00 - 2019-01-15 00:00:00
# CPU times: user 224 ms, sys: 88.1 ms, total: 313 ms
# Wall time: 312 ms
# **** Data increment: index 1568 - 1571, 2019-01-16 00:00:00 - 2019-01-19 00:00:00
# CPU times: user 242 ms, sys: 56.4 ms, total: 298 ms
# Wall time: 297 ms
# **** Data increment: index 1572 - 1575, 2019-01-20 00:00:00 - 2019-01-23 00:00:00
# CPU times: user 241 ms, sys: 56 ms, total: 297 ms
# Wall time: 296 ms
# **** Data increment: index 1576 - 1579, 2019-01-24 00:00:00 - 2019-01-27 00:00:00
# CPU times: user 220 ms, sys: 75 ms, total: 295 ms
# Wall time: 294 ms
# **** Data increment: index 1580 - 1583, 2019-01-28 00:00:00 - 2019-01-31 00:00:00
# CPU times: user 229 ms, sys: 68.4 ms, total: 298 ms
# Wall time: 297 ms
# **** Data increment: index 1584 - 1587, 2019-02-01 00:00:00 - 2019-02-04 00:00:00
# CPU times: user 228 ms, sys: 62.3 ms, total: 290 ms
# Wall time: 290 ms
# **** Data increment: index 1588 - 1591, 2019-02-05 00:00:00 - 2019-02-08 00:00:00
# CPU times: user 234 ms, sys: 59 ms, total: 293 ms
# Wall time: 293 ms
# **** Data increment: index 1592 - 1595, 2019-02-09 00:00:00 - 2019-02-12 00:00:00
# CPU times: user 240 ms, sys: 55.8 ms, total: 296 ms
# Wall time: 295 ms
# **** Data increment: index 1596 - 1599, 2019-02-13 00:00:00 - 2019-02-16 00:00:00
# CPU times: user 228 ms, sys: 71.8 ms, total: 300 ms
# Wall time: 299 ms
# **** Data increment: index 1600 - 1603, 2019-02-17 00:00:00 - 2019-02-20 00:00:00
# CPU times: user 241 ms, sys: 78.8 ms, total: 320 ms
# Wall time: 320 ms
# **** Data increment: index 1604 - 1607, 2019-02-21 00:00:00 - 2019-02-24 00:00:00
# CPU times: user 231 ms, sys: 63.3 ms, total: 294 ms
# Wall time: 293 ms
# **** Data increment: index 1608 - 1611, 2019-02-25 00:00:00 - 2019-02-28 00:00:00
# CPU times: user 243 ms, sys: 53 ms, total: 296 ms
# Wall time: 295 ms
# **** Data increment: index 1612 - 1615, 2019-03-01 00:00:00 - 2019-03-04 00:00:00
# CPU times: user 235 ms, sys: 61 ms, total: 296 ms
# Wall time: 296 ms
# **** Data increment: index 1616 - 1619, 2019-03-05 00:00:00 - 2019-03-08 00:00:00
# CPU times: user 232 ms, sys: 64.5 ms, total: 296 ms
# Wall time: 296 ms
# **** Data increment: index 1620 - 1623, 2019-03-09 00:00:00 - 2019-03-12 00:00:00
# CPU times: user 235 ms, sys: 65 ms, total: 300 ms
# Wall time: 299 ms
# **** Data increment: index 1624 - 1627, 2019-03-13 00:00:00 - 2019-03-16 00:00:00
# CPU times: user 243 ms, sys: 51.3 ms, total: 294 ms
# Wall time: 293 ms
# **** Data increment: index 1628 - 1631, 2019-03-17 00:00:00 - 2019-03-20 00:00:00
# CPU times: user 261 ms, sys: 65.7 ms, total: 327 ms
# Wall time: 451 ms
# **** Data increment: index 1632 - 1635, 2019-03-21 00:00:00 - 2019-03-24 00:00:00
# CPU times: user 264 ms, sys: 69.2 ms, total: 333 ms
# Wall time: 461 ms
# **** Data increment: index 1636 - 1639, 2019-03-25 00:00:00 - 2019-03-28 00:00:00
# CPU times: user 258 ms, sys: 72.7 ms, total: 331 ms
# Wall time: 430 ms
# **** Data increment: index 1640 - 1643, 2019-03-29 00:00:00 - 2019-04-01 00:00:00
# CPU times: user 230 ms, sys: 91 ms, total: 321 ms
# Wall time: 366 ms
# **** Data increment: index 1644 - 1647, 2019-04-02 00:00:00 - 2019-04-05 00:00:00
# CPU times: user 276 ms, sys: 55.6 ms, total: 331 ms
# Wall time: 354 ms
# **** Data increment: index 1648 - 1651, 2019-04-06 00:00:00 - 2019-04-09 00:00:00
# CPU times: user 249 ms, sys: 52.3 ms, total: 302 ms
# Wall time: 390 ms
# **** Data increment: index 1652 - 1655, 2019-04-10 00:00:00 - 2019-04-13 00:00:00
# CPU times: user 241 ms, sys: 72.2 ms, total: 313 ms
# Wall time: 334 ms
# **** Data increment: index 1656 - 1659, 2019-04-14 00:00:00 - 2019-04-17 00:00:00
# CPU times: user 305 ms, sys: 53.6 ms, total: 359 ms
# Wall time: 659 ms
# **** Data increment: index 1660 - 1663, 2019-04-18 00:00:00 - 2019-04-21 00:00:00
# CPU times: user 258 ms, sys: 52.7 ms, total: 311 ms
# Wall time: 310 ms
# **** Data increment: index 1664 - 1667, 2019-04-22 00:00:00 - 2019-04-25 00:00:00
# CPU times: user 230 ms, sys: 68.8 ms, total: 299 ms
# Wall time: 298 ms
# **** Data increment: index 1668 - 1671, 2019-04-26 00:00:00 - 2019-04-29 00:00:00
# CPU times: user 245 ms, sys: 56.3 ms, total: 302 ms
# Wall time: 301 ms
# **** Data increment: index 1672 - 1675, 2019-04-30 00:00:00 - 2019-05-03 00:00:00
# CPU times: user 258 ms, sys: 60.5 ms, total: 319 ms
# Wall time: 318 ms
# **** Data increment: index 1676 - 1679, 2019-05-04 00:00:00 - 2019-05-07 00:00:00
# CPU times: user 265 ms, sys: 30.4 ms, total: 295 ms
# Wall time: 294 ms
# **** Data increment: index 1680 - 1683, 2019-05-08 00:00:00 - 2019-05-11 00:00:00
# CPU times: user 244 ms, sys: 67.5 ms, total: 312 ms
# Wall time: 311 ms
# **** Data increment: index 1684 - 1687, 2019-05-12 00:00:00 - 2019-05-15 00:00:00
# CPU times: user 233 ms, sys: 40.1 ms, total: 273 ms
# Wall time: 273 ms
# **** Data increment: index 1688 - 1691, 2019-05-16 00:00:00 - 2019-05-19 00:00:00
# CPU times: user 250 ms, sys: 32.5 ms, total: 283 ms
# Wall time: 282 ms
# **** Data increment: index 1692 - 1695, 2019-05-20 00:00:00 - 2019-05-23 00:00:00
# CPU times: user 267 ms, sys: 27 ms, total: 294 ms
# Wall time: 293 ms
# **** Data increment: index 1696 - 1699, 2019-05-24 00:00:00 - 2019-05-27 00:00:00
# CPU times: user 257 ms, sys: 39.6 ms, total: 297 ms
# Wall time: 296 ms
# **** Data increment: index 1700 - 1703, 2019-05-28 00:00:00 - 2019-05-31 00:00:00
# CPU times: user 251 ms, sys: 40.7 ms, total: 291 ms
# Wall time: 291 ms
# **** Data increment: index 1704 - 1707, 2019-06-01 00:00:00 - 2019-06-04 00:00:00
# CPU times: user 235 ms, sys: 35.1 ms, total: 270 ms
# Wall time: 269 ms
# **** Data increment: index 1708 - 1711, 2019-06-05 00:00:00 - 2019-06-08 00:00:00
# CPU times: user 261 ms, sys: 32.2 ms, total: 294 ms
# Wall time: 292 ms
# **** Data increment: index 1712 - 1715, 2019-06-09 00:00:00 - 2019-06-12 00:00:00
# CPU times: user 251 ms, sys: 24.8 ms, total: 276 ms
# Wall time: 275 ms
# **** Data increment: index 1716 - 1719, 2019-06-13 00:00:00 - 2019-06-16 00:00:00
# CPU times: user 231 ms, sys: 35.2 ms, total: 266 ms
# Wall time: 265 ms
# **** Data increment: index 1720 - 1723, 2019-06-17 00:00:00 - 2019-06-20 00:00:00
# CPU times: user 238 ms, sys: 48.4 ms, total: 286 ms
# Wall time: 285 ms
# **** Data increment: index 1724 - 1727, 2019-06-21 00:00:00 - 2019-06-24 00:00:00
# CPU times: user 237 ms, sys: 35.9 ms, total: 272 ms
# Wall time: 272 ms
# **** Data increment: index 1728 - 1731, 2019-06-25 00:00:00 - 2019-06-28 00:00:00
# CPU times: user 281 ms, sys: 19.9 ms, total: 301 ms
# Wall time: 300 ms
# **** Data increment: index 1732 - 1735, 2019-06-29 00:00:00 - 2019-07-02 00:00:00
# CPU times: user 249 ms, sys: 23.8 ms, total: 272 ms
# Wall time: 272 ms
# **** Data increment: index 1736 - 1739, 2019-07-03 00:00:00 - 2019-07-06 00:00:00
# CPU times: user 248 ms, sys: 20.2 ms, total: 268 ms
# Wall time: 268 ms
# **** Data increment: index 1740 - 1743, 2019-07-07 00:00:00 - 2019-07-10 00:00:00
# CPU times: user 224 ms, sys: 27.7 ms, total: 252 ms
# Wall time: 251 ms
# **** Data increment: index 1744 - 1747, 2019-07-11 00:00:00 - 2019-07-14 00:00:00
# CPU times: user 220 ms, sys: 19.9 ms, total: 240 ms
# Wall time: 268 ms
# **** Data increment: index 1748 - 1751, 2019-07-15 00:00:00 - 2019-07-18 00:00:00
# CPU times: user 237 ms, sys: 36 ms, total: 273 ms
# Wall time: 324 ms
# **** Data increment: index 1752 - 1755, 2019-07-19 00:00:00 - 2019-07-22 00:00:00
# CPU times: user 211 ms, sys: 23.1 ms, total: 234 ms
# Wall time: 270 ms
# **** Data increment: index 1756 - 1759, 2019-07-23 00:00:00 - 2019-07-26 00:00:00
# CPU times: user 207 ms, sys: 20.8 ms, total: 228 ms
# Wall time: 283 ms
# **** Data increment: index 1760 - 1763, 2019-07-27 00:00:00 - 2019-07-30 00:00:00
# CPU times: user 214 ms, sys: 14.9 ms, total: 229 ms
# Wall time: 533 ms
# **** Data increment: index 1764 - 1767, 2019-07-31 00:00:00 - 2019-08-03 00:00:00
# CPU times: user 245 ms, sys: 19.8 ms, total: 264 ms
# Wall time: 386 ms
# **** Data increment: index 1768 - 1771, 2019-08-04 00:00:00 - 2019-08-07 00:00:00
# CPU times: user 208 ms, sys: 14.1 ms, total: 222 ms
# Wall time: 271 ms
# **** Data increment: index 1772 - 1775, 2019-08-08 00:00:00 - 2019-08-11 00:00:00
# CPU times: user 235 ms, sys: 19.3 ms, total: 255 ms
# Wall time: 418 ms
# **** Data increment: index 1776 - 1779, 2019-08-12 00:00:00 - 2019-08-15 00:00:00
# CPU times: user 224 ms, sys: 9.02 ms, total: 233 ms
# Wall time: 354 ms
# **** Data increment: index 1780 - 1783, 2019-08-16 00:00:00 - 2019-08-19 00:00:00
# CPU times: user 226 ms, sys: 19 ms, total: 245 ms
# Wall time: 439 ms
# **** Data increment: index 1784 - 1787, 2019-08-20 00:00:00 - 2019-08-23 00:00:00
# CPU times: user 248 ms, sys: 13.3 ms, total: 262 ms
# Wall time: 541 ms
# **** Data increment: index 1788 - 1791, 2019-08-24 00:00:00 - 2019-08-27 00:00:00
# CPU times: user 229 ms, sys: 21.5 ms, total: 250 ms
# Wall time: 465 ms
# **** Data increment: index 1792 - 1795, 2019-08-28 00:00:00 - 2019-08-31 00:00:00
# CPU times: user 226 ms, sys: 8.21 ms, total: 234 ms
# Wall time: 426 ms
# **** Data increment: index 1796 - 1799, 2019-09-01 00:00:00 - 2019-09-04 00:00:00
# CPU times: user 203 ms, sys: 15.2 ms, total: 218 ms
# Wall time: 364 ms
# **** Data increment: index 1800 - 1803, 2019-09-05 00:00:00 - 2019-09-08 00:00:00
# CPU times: user 217 ms, sys: 7.91 ms, total: 225 ms
# Wall time: 365 ms
# **** Data increment: index 1804 - 1807, 2019-09-09 00:00:00 - 2019-09-12 00:00:00
# CPU times: user 253 ms, sys: 21.5 ms, total: 274 ms
# Wall time: 410 ms
# **** Data increment: index 1808 - 1811, 2019-09-13 00:00:00 - 2019-09-16 00:00:00
# CPU times: user 214 ms, sys: 24.6 ms, total: 239 ms
# Wall time: 669 ms
# **** Data increment: index 1812 - 1815, 2019-09-17 00:00:00 - 2019-09-20 00:00:00
# CPU times: user 252 ms, sys: 15.5 ms, total: 268 ms
# Wall time: 373 ms
# **** Data increment: index 1816 - 1819, 2019-09-21 00:00:00 - 2019-09-24 00:00:00
# CPU times: user 279 ms, sys: 16.8 ms, total: 296 ms
# Wall time: 427 ms
# **** Data increment: index 1820 - 1823, 2019-09-25 00:00:00 - 2019-09-28 00:00:00
# CPU times: user 231 ms, sys: 28.9 ms, total: 260 ms
# Wall time: 346 ms
# **** Data increment: index 1824 - 1824, 2019-09-29 00:00:00 - 2019-09-29 00:00:00
# CPU times: user 163 ms, sys: 15.1 ms, total: 178 ms
# Wall time: 178 ms
# 2020-04-01T19:43:01Z

# %% [markdown]
# ### Processing times for writing the whole 25 GB dataset to zarr
# - **To zarr on AWS**
#     - 3/31: 94 minutes, using `model_increment = 460` and `chunk= {'time': 460, 'x': 150, 'y': 150}`. Increments were 20-23 min.
#     - 3/31: 4 hr 32 min, using `model_increment = 4` and `chunk= {'time': 4}`. Increments were 5 - 57 secs
# - **To zarr on local file system**
#     - 3/30 7:30pm: 2 min, using `chunk = {'time': 400, 'x': 200, 'y': 200}`. Each increment took 7.7 - 15 seconds. The size of the chunk files is 5 - 45 MB

# %% [markdown]
# ## Read zarr dataset back, for verification

# %%
zds = xr.open_zarr(
    store=zarrstore, 
    consolidated=True
)

# %%
zds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1825, x: 1382, y: 2476)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-10-01 2014-10-02 ... 2019-09-29
#   * x        (x) int64 487200 487300 487400 487500 ... 625100 625200 625300
#   * y        (y) int64 4690100 4690200 4690300 ... 4937400 4937500 4937600
# Data variables:
#     swe      (time, y, x) float32 dask.array<chunksize=(4, 2476, 1382), meta=np.ndarray>
# Attributes:
#     CRS:          UTM Zone 12N, EPSG:32612
#     description:  SnowModel model run, SWE variable only

# %%
zds.swe.encoding
# Out:
# {'chunks': (4, 2476, 1382),
#  'compressor': Blosc(cname='lz4', clevel=5, shuffle=SHUFFLE, blocksize=0),
#  'filters': None,
#  '_FillValue': nan,
#  'dtype': dtype('float32')}

# %%
zds.swe.attrs
# Out:
# {'long_name': 'Snow Water Equivalent',
#  'standard_name': 'lwe_thickness_of_surface_snow_amount',
#  'units': 'meters',
#  'valid_min': 0.0}

# %% [markdown]
# ### Changing the attributes using zarr directly, *after* creating the zarr dataset
# Use this code to modify global and variable attributes of existing zarr datasets.

# %%
# zarr.open_consolidated doesn't allow changing the metadata
# zstore = zarr.open_consolidated(store=zarrstore, mode='r+')

# zstore = zarr.open(store=zarrstore, mode='r+')

# %%
# zstore.attrs['new_appended_attr'] = 'my appended attribute'
# zstore.swe.attrs['swe_append_attr'] = 'my swe appended attribute'

# %%
# Must pass the zarr store path, not the opened zstore
# zarr.consolidate_metadata(zarrstore)
